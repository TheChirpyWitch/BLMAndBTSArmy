# %%
# Read text (tweet) and userdescription from CSV file using Pandas
# timestamp , text , user_id , user_description ,  
import pandas as pd
df=pd.read_csv("originalTweet_841_4columns.csv", sep=r'\s*,\s*', header=0, encoding='utf8')
#print(df.shape)
#print(df.columns.tolist())
tweets=df['text']
#print(tweets)
# Out:
# /opt/anaconda3/envs/SNA/lib/python3.7/site-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.

# %%
# clean text using NLTK
import nltk
#nltk.download()
from nltk.tokenize import TweetTokenizer
tknzr = TweetTokenizer()
#s0 = "This is a cooool #dummysmiley: :-) :-P <3 and some arrows < > -> <--"
tokens=[]
for tweet in tweets:
    tokens.append(tknzr.tokenize(tweet))
print(tokens)
# Out:
# [['Lets', '#MatchAMillion', 'with', '@OneInAnARMY', '\\', 'u2019s', 'links', '!', '!', 'https://t.co/y8oD0rb8EL', '#BlackLivesMatter', '@BTS_twt'], ['#MatchAMillion', "Don't", 'be', 'afraid', 'to', 'put', 'your', 'money', 'in', 'the', 'organizations', 'in', 'this', 'link', '.', "It's", 'organized', 'by', '@OneInAnARMY', '.', '\\', 'u2026', 'https://t.co/dBx6O1W74x'], ['ARMYs', "let's", '#MatchAMillion', 'https://t.co/MiDgAZX2Vx'], ['@naija0329', 'donate', '!', '!', '#MatchAMillion'], ['@naija0329', '@OneInAnARMY', 'Are', 'we', 'focusing', 'on', 'one', 'org', 'or', 'a', '#MatchAMillion', 'across', 'all', '?'], ["What's", 'so', 'great', 'is', 'you', 'can', 'actually', 'see', 'a', 'break', 'down', 'of', 'where', 'your', 'funds', 'are', 'going', '!', 'And', 'OIAA', 'will', 'be', 'able', 'to', 'track', '\\', 'u2026', 'https://t.co/fBTdshzP6H'], ['It', 'took', 'less', 'than', 'five', 'minutes', 'to', 'donate', '!', '!', '#MatchAMillion', 'https://t.co/G4oGBRAPt2'], ['I', 'made', 'a', 'contribution', 'earlier', 'in', 'the', 'week', 'but', 'I', 'don', '\\', 'u2019t', 'mind', 'contributing', 'again', 'in', 'the', 'name', 'of', '@BTS_twt', 'and', 'ARMY', '\\', 'u2026', 'https://t.co/EeJZCM1avz'], ['.', '#MatchAMillion', '\\', 'n', '\\', 'nhttps', ':/', '/', 't.co/dDhY8GIzoq', 'https://t.co/zKOOtZHGQn'], ['i', 'made', 'a', 'second', 'donation', 'to', 'blm', 'this', 'time', 'with', 'the', 'bts', 'army', '\\', 'ud83d', '\\', 'ude', '0a', '@BTS_twt', 'raised', 'the', 'bar', 'let', '\\', 'u2019s', '#MatchAMillion', '\\', 'ud83d', '\\', 'udc', '9c', '\\', 'n', '\\', 'n', '\\', 'ud83d', '\\', 'udd', '17', '\\', 'u2026', 'https://t.co/r27xnnRT5E'], ['@shookytwts', '#MatchAMillion'], ['@PopCrave', '@Zak5678845', '@Variety', '@BTS_twt', '@BigHitEnt', 'Incredibly', 'proud', 'of', 'calling', 'them', 'my', 'singers', '.', 'We', 'have', 'also', 'been', 'd', '\\', 'u2026', 'https://t.co/xAna8jQe5k'], ['@BTS_twt', 'we', 'coming', '!', '!', '!', '#MatchAMillion'], ['@OneInAnARMY', 'has', 'a', 'donation', 'link', 'where', 'you', 'can', 'keep', 'track', 'of', 'your', 'donations', 'with', 'receipts', 'when', 'you', 'choose', 'to', 'split', '\\', 'u2026', 'https://t.co/zWqShbGZmo'], ['Nothing', 'is', 'impossible', 'if', 'we', 'work', 'together', '.', '@BTS_twt', '\\', 'n', '\\', 'n', '#MatchAMillion', '\\', 'n', '\\', 'n', 'https://t.co/uRa7van4FW'], ['#matchamillion'], ['listen', '...', "I'm", 'broke', '\\', 'u270b', '\\', 'ud83d', '\\', 'ude', '14', '#BlackLivesMatter', '#MatchaMillion', 'https://t.co/oKTseiIBTP'], ['ARMY', '#MatchAMillion', '\\', 'n', '@BTS_twt', 'https://t.co/2bbjiDnIjW'], ['#MatchAMillion', '\\', 'nLETS', 'GOOOOO', '\\', 'nhttps', ':/', '/', 't.co/3qkiE1kLp8', 'https://t.co/t2S3vYGfxj', 'https://t.co/8v4nYtCjII'], ['#MatchAMillion', '\\', 'nWe', 'are', '26', 'TWENTY', 'SIX', 'times', 'a', 'million', 'fam', '.', '\\', 'n', '\\', 'nLet', '\\', 'u2019s', 'get', 'it', '!', '\\', 'ud83d', '\\', 'udc', '9c', '\\', 'n', '\\', 'n', 'https://t.co/FOxuMiszag'], ['@modooborahae', 'Thank', 'you', '#MatchAMillion', '#BlackLivesMatter'], ['\\', 'ud83d', '\\', 'udc', '9c', '\\', 'ud83e', '\\', 'udd', '70', '\\', 'u2728', '\\', 'n', '\\', 'n', '#MatchAMillion', '#BlackLivesMatter', '@BTS_twt', 'https://t.co/ylgZi1VDf3', 'https://t.co/IEPEG5S2n6'], ['IF', 'ANYONE', 'CAN', 'MATCH', 'PLEASE', 'DO', '.', 'WE', 'GON', 'MATCH', 'BTS', 'YES', 'TF', 'WE', 'WILL', '\\', 'ud83d', '\\', 'ude', '0a', '\\', 'ud83d', '\\', 'udc', '9c', '#MatchAMillion', '\\', 'nhttps', ':/', '/', 't.co/f4XlNV4WUU\\u2026', 'https://t.co/14MIHwwuoV'], ['let', 'me', 'double', 'that', 'real', 'quick', '\\', 'n', '#MatchAMillion', '\\', 'nhttps', ':/', '/', 't.co/e3cLfJJOt1', 'https://t.co/VdkfSorOxw', 'https://t.co/A1RDLTrK5h'], ['#MatchAMillion', '!', '\\', 'ud83d', '\\', 'udc', '9c', '\\', 'ncarrd', 'in', 'the', 'quote', '!', "Let's", 'get', 'it', '!', 'https://t.co/gRXDLAjv83', 'https://t.co/kxY8omMWZ5'], ['\\', 'ud83d', '\\', 'udc', '9cARMYxBLM', '\\', 'n', '\\', 'n', '#MatchAMilli ...

# %%
#
# compute embedding vectors from text
import numpy as np
from embedding_as_service.text.encode import Encoder

#embed = Encoder(embedding='bert', model='bert_base_uncased', download=True) 
embed = Encoder(embedding='word2vec', model='google_news_300')
vecs = embed.encode(tokens, is_tokenized=True)
vecs = np.squeeze(vecs)
vecs.shape
# Out:
# (841, 128, 300)

# %%
# compute cos similarity between two tweets
from sklearn.metrics.pairwise import cosine_similarity
tw1=vecs[0].reshape(1,-1)
tw2=vecs[100].reshape(1,-1)
print('CosSim(Tweet[0], Tweet[100])', cosine_similarity(tw1, tw2))
# Out:
# CosSim(Tweet[0], Tweet[100]) [[0.]]
